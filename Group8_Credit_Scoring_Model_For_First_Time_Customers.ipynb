# %%
import pandas as pd
import numpy as np
#import the Applicant's biographical information
application = pd.read_csv('./data/application-record-final.csv')
application
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y             0
# 1     5008805           M            Y               Y             0
# 2     5008806           M            Y               Y             0
# 3     5008810           F            N               Y             0
# 4     5008811           F            N               Y             0
# ...       ...         ...          ...             ...           ...
# 2495  5024320           F            N               Y             0
# 2496  5024321           F            N               Y             0
# 2497  5024324           F            N               Y             0
# 2498  5024326           F            N               Y             0
# 2499  5024328           F            N               Y             0
#
#       AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
#Ouputting sample data from the dataset to get a better understanding of the data we are working with

# %%
application.tail(15)
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2485  5024301           F            N               Y             0
# 2486  5024307           F            N               Y             1
# 2487  5024309           F            N               Y             1
# 2488  5024310           F            N               Y             0
# 2489  5024311           F            N               Y             0
# 2490  5024313           F            N               Y             0
# 2491  5024314           F            N               Y             0
# 2492  5024316           F            N               Y             0
# 2493  5024317           F            N               Y             0
# 2494  5024319           F            N               Y             0
# 2495  5024320           F            N               Y             0
# 2496  5024321           F            N               Y             0
# 2497  5024324           F            N               Y             0
# ...

# %%
#748 NaN in occupation type, meaning that for 748 of our applicants the occupation type is not documented
application.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2500 non-null   int64
#  1   CODE_GENDER          2500 non-null   object
#  2   FLAG_OWN_CAR         2500 non-null   object
#  3   FLAG_OWN_REALTY      2500 non-null   object
#  4   CNT_CHILDREN         2500 non-null   int64
#  5   AMT_INCOME_TOTAL     2500 non-null   int64
#  6   NAME_INCOME_TYPE     2500 non-null   object
#  7   NAME_EDUCATION_TYPE  2500 non-null   object
#  8   NAME_FAMILY_STATUS   2500 non-null   object
#  9   NAME_HOUSING_TYPE    2500 non-null   object
#  10  DAYS_BIRTH           2500 non-null   int64
#  11  DAYS_EMPLOYED        2500 non-null   int64
#  12  FLAG_MOBIL           2500 non-null   int64
#  13  FLAG_WORK_PHONE      2500 non-null   int64
#  14  FLAG_PHONE           2500 non-null   int64
# ...

# %%
#obtaining key statistical information
application.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  \
# count  2.500000e+03   2500.000000      2.500000e+03   2500.000000
# mean   5.017277e+06      0.399200      1.955443e+05 -16172.378400
# std    6.347957e+03      0.680018      1.142462e+05   4051.143276
# min    5.008804e+06      0.000000      3.330000e+04 -25140.000000
# 25%    5.010104e+06      0.000000      1.260000e+05 -19702.000000
# 50%    5.021529e+06      0.000000      1.800000e+05 -15675.000000
# 75%    5.022930e+06      1.000000      2.250000e+05 -12847.000000
# max    5.024328e+06      3.000000      1.350000e+06  -8128.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE   FLAG_PHONE  FLAG_EMAIL  \
# count    2500.000000      2500.0      2500.000000  2500.000000  2500.00000
# mean    58941.571200         1.0         0.183200     0.316400     0.14400
# std    137486.145839         0.0         0.386908     0.465164     0.35116
# ...

# %%
#obtaining key statistical information
application['AMT_INCOME_TOTAL'].describe()
# Out:
# count    2.500000e+03
# mean     1.955443e+05
# std      1.142462e+05
# min      3.330000e+04
# 25%      1.260000e+05
# 50%      1.800000e+05
# 75%      2.250000e+05
# max      1.350000e+06
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
application.shape
# Out:
# (2500, 18)

# %%
#Understanding the Application Record data
pd.set_option('display.max_colwidth', None)
application_record_dictionary = pd.read_csv('./data/application-record-dictionary.csv')
application_record_dictionary
# Out:
#            Feature name               Explanation  \
# 0                    ID             Client number
# 1           CODE_GENDER                    Gender
# 2          FLAG_OWN_CAR            Is there a car
# 3       FLAG_OWN_REALTY       Is there a property
# 4          CNT_CHILDREN        Number of children
# 5      AMT_INCOME_TOTAL             Annual income
# 6      NAME_INCOME_TYPE           Income category
# 7   NAME_EDUCATION_TYPE           Education level
# 8    NAME_FAMILY_STATUS            Marital status
# 9     NAME_HOUSING_TYPE             Way of living
# 10           DAYS_BIRTH                  Birthday
# 11        DAYS_EMPLOYED  Start date of employment
# 12           FLAG_MOBIL   Is there a mobile phone
# 13      FLAG_WORK_PHONE     Is there a work phone
# 14           FLAG_PHONE          Is there a phone
# 15           FLAG_EMAIL         Is there an email
# 16      OCCUPATION_TYPE                Occupation
# 17      CNT_FAM_MEMBERS               Family size
#
# ...

# %%
application.isnull().sum().sort_values(ascending=False)
# Out:
# OCCUPATION_TYPE        748
# ID                       0
# CODE_GENDER              0
# FLAG_EMAIL               0
# FLAG_PHONE               0
# FLAG_WORK_PHONE          0
# FLAG_MOBIL               0
# DAYS_EMPLOYED            0
# DAYS_BIRTH               0
# NAME_HOUSING_TYPE        0
# NAME_FAMILY_STATUS       0
# NAME_EDUCATION_TYPE      0
# NAME_INCOME_TYPE         0
# AMT_INCOME_TOTAL         0
# CNT_CHILDREN             0
# FLAG_OWN_REALTY          0
# FLAG_OWN_CAR             0
# CNT_FAM_MEMBERS          0
# dtype: int64

# %%
#make sure we don't have any outlying data contradicting to the data dictionary. For example, we confirm that we have 2500 unique IDs and no more than 2 genders.
application.nunique()
# Out:
# ID                     2500
# CODE_GENDER               2
# FLAG_OWN_CAR              2
# FLAG_OWN_REALTY           2
# CNT_CHILDREN              4
# AMT_INCOME_TOTAL         96
# NAME_INCOME_TYPE          5
# NAME_EDUCATION_TYPE       5
# NAME_FAMILY_STATUS        5
# NAME_HOUSING_TYPE         6
# DAYS_BIRTH              849
# DAYS_EMPLOYED           503
# FLAG_MOBIL                1
# FLAG_WORK_PHONE           2
# FLAG_PHONE                2
# FLAG_EMAIL                2
# OCCUPATION_TYPE          17
# CNT_FAM_MEMBERS           5
# dtype: int64

# %%
application['ID'].value_counts()
# Out:
# 5008804    1
# 5022447    1
# 5022434    1
# 5022435    1
# 5022442    1
#           ..
# 5010558    1
# 5010559    1
# 5010560    1
# 5010567    1
# 5024328    1
# Name: ID, Length: 2500, dtype: int64

# %%
application['CODE_GENDER'].value_counts()
# Out:
# F    1666
# M     834
# Name: CODE_GENDER, dtype: int64

# %%
application['FLAG_OWN_CAR'].value_counts()
# Out:
# N    1465
# Y    1035
# Name: FLAG_OWN_CAR, dtype: int64

# %%
application['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    1790
# N     710
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
#1759 applicants do not have children
application['CNT_CHILDREN'].value_counts()
# Out:
# 0    1759
# 1     505
# 2     215
# 3      21
# Name: CNT_CHILDREN, dtype: int64

# %%
application['AMT_INCOME_TOTAL'].value_counts()
# Out:
# 135000    282
# 157500    207
# 202500    206
# 180000    199
# 225000    174
#          ...
# 288000      1
# 143100      1
# 432000      1
# 196650      1
# 211500      1
# Name: AMT_INCOME_TOTAL, Length: 96, dtype: int64

# %%
application['NAME_INCOME_TYPE'].value_counts()
# Out:
# Working                 1267
# Commercial associate     621
# Pensioner                423
# State servant            183
# Student                    6
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
application['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary / secondary special    1698
# Higher education                  654
# Incomplete higher                 125
# Lower secondary                    22
# Academic degree                     1
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
application['NAME_FAMILY_STATUS'].value_counts()
# Out:
# Married                 1720
# Single / not married     306
# Civil marriage           197
# Separated                164
# Widow                    113
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
application['NAME_HOUSING_TYPE'].value_counts()
# Out:
# House / apartment      2255
# With parents             99
# Municipal apartment      72
# Rented apartment         55
# Co-op apartment          10
# Office apartment          9
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
dirth=application['DAYS_BIRTH'].value_counts()
dirth
# Out:
# -15519    24
# -13790    13
# -14100    12
# -15675    12
# -15140    12
#           ..
# -11642     1
# -11925     1
# -21275     1
# -11055     1
# -17401     1
# Name: DAYS_BIRTH, Length: 849, dtype: int64

# %%
dirth.sort_index()
# Out:
# -25140    2
# -24742    1
# -24629    1
# -24311    3
# -24278    3
#          ..
# -8477     5
# -8378     1
# -8231     2
# -8182     1
# -8128     1
# Name: DAYS_BIRTH, Length: 849, dtype: int64

# %%
demploy=application['DAYS_EMPLOYED'].value_counts()
demploy
# Out:
#  365243    419
# -3234       24
# -678        21
# -2712       17
# -3873       14
#           ...
# -1982        1
# -2131        1
# -5287        1
# -2744        1
# -9559        1
# Name: DAYS_EMPLOYED, Length: 503, dtype: int64

# %%
demploy.sort_index()
# Out:
# -14127       1
# -13415       1
# -11954       3
# -11693       5
# -11589       3
#           ...
# -122        11
# -99          4
# -93          1
# -91          3
#  365243    419
# Name: DAYS_EMPLOYED, Length: 503, dtype: int64

# %%
application['FLAG_MOBIL'].value_counts()
# Out:
# 1    2500
# Name: FLAG_MOBIL, dtype: int64

# %%
application['FLAG_WORK_PHONE'].value_counts()
# Out:
# 0    2042
# 1     458
# Name: FLAG_WORK_PHONE, dtype: int64

# %%
application['FLAG_PHONE'].value_counts()
# Out:
# 0    1709
# 1     791
# Name: FLAG_PHONE, dtype: int64

# %%
application['FLAG_EMAIL'].value_counts()
# Out:
# 0    2140
# 1     360
# Name: FLAG_EMAIL, dtype: int64

# %%
application['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 390
# Sales staff              259
# Core staff               246
# Managers                 213
# Drivers                  183
# Accountants               86
# High skill tech staff     77
# Medicine staff            71
# Cooking staff             71
# Security staff            55
# Cleaning staff            44
# Private service staff     26
# Secretaries               12
# Low-skill Laborers         9
# Realty agents              6
# Waiters/barmen staff       2
# HR staff                   2
# Name: OCCUPATION_TYPE, dtype: int64

# %%
application['CNT_FAM_MEMBERS'].value_counts().sort_index()
# Out:
# 1     478
# 2    1372
# 3     428
# 4     201
# 5      21
# Name: CNT_FAM_MEMBERS, dtype: int64

# %%
#Picking a random sample of 10 applicants
application[['ID','CODE_GENDER','AMT_INCOME_TOTAL','OCCUPATION_TYPE']].sample(10)
# Out:
#            ID CODE_GENDER  AMT_INCOME_TOTAL        OCCUPATION_TYPE
# 919   5010768           M            135000               Laborers
# 20    5008851           M            112500                Drivers
# 2076  5023370           M            135000                Drivers
# 1853  5022873           F            225000  Private service staff
# 1222  5021463           F            225000             Core staff
# 808   5010501           F             90000            Sales staff
# 1292  5021622           F            126000               Managers
# 2312  5023955           M            292500               Managers
# 51    5008927           F            297000               Laborers
# 74    5008981           M            112500                Drivers

# %%
#Importing the 6 month history of credit payments by each customer
import pandas as pd
import numpy as np
credit = pd.read_csv('./data/credit-record-final.csv')
credit
# Out:
#             ID  MONTHS_BALANCE STATUS
# 0      5008804               0      C
# 1      5008804              -1      C
# 2      5008804              -2      C
# 3      5008804              -3      C
# 4      5008804              -4      C
# ...        ...             ...    ...
# 14995  5024328              -1      C
# 14996  5024328              -2      C
# 14997  5024328              -3      C
# 14998  5024328              -4      0
# 14999  5024328              -5      0
#
# [15000 rows x 3 columns]

# %%
credit.shape
# Out:
# (15000, 3)

# %%
credit['MONTHS_BALANCE'].value_counts()
# Out:
#  0    2500
# -1    2500
# -2    2500
# -3    2500
# -4    2500
# -5    2500
# Name: MONTHS_BALANCE, dtype: int64

# %%
#Understanding the Credit Record data
credit_record_dictionary = pd.read_csv('./data/credit-record-dictionary.csv')
credit_record_dictionary
# Out:
#      Feature name    Explanation  \
# 0              ID  Client number
# 1  MONTHS_BALANCE   Record month
# 2          STATUS         Status
#
#                                                                                                                                                                                                                         Remarks
# 0                                                                                                                                                                                                                             -
# 1                                                                                                 The month of the extracted data is the starting point, backwards, 0 is the current month, -1 is the previous month, and so on
# ...

# %%
#Setting a clear evaluation criteria for assigning credit score points out of 100 maximum
evaluation_criteria_dictionary = pd.read_csv('./data/evaluation-criteria-dictionary.csv')
evaluation_criteria_dictionary
# Out:
#             Column Title           Points
# 0                      -                -
# 1       NAME_INCOME_TYPE  Points Assigned
# 2              Pensioner                8
# 3   Commercial associate                6
# 4                Working                5
# 5          State servant                7
# 6                Student                3
# 7                      -                -
# 8     NAME_FAMILY_STATUS  Points Assigned
# 9                Married                6
# 10  Single / not married                2
# 11        Civil marriage                4
# 12             Separated                3
# 13                 Widow                4
# 14                     -                -
# 15     NAME_HOUSING_TYPE  Points Assigned
# 16     House / apartment                4
# 17          With parents                3
# 18   Municipal apartment                1
# 19      Rented apartment                2
# 20       Co-op apartment                3
# ...

# %%
#Assigning the credit score points based on the status for each month

# %%
conditions=[
    (credit['STATUS']=='C'),
    (credit['STATUS']=='0'),
    (credit['STATUS']=='X'),
    (credit['STATUS']=='1'),
    (credit['STATUS']=='2'),
    (credit['STATUS']=='3'),
    (credit['STATUS']=='4'),
    (credit['STATUS']=='5')
]

# %%
values=['60','60', '50','50','40','30','20','0']

# %%
credit['CREDIT_SCORE'] = np.select(conditions,values)

# %%
credit
# Out:
#             ID  MONTHS_BALANCE STATUS CREDIT_SCORE
# 0      5008804               0      C           60
# 1      5008804              -1      C           60
# 2      5008804              -2      C           60
# 3      5008804              -3      C           60
# 4      5008804              -4      C           60
# ...        ...             ...    ...          ...
# 14995  5024328              -1      C           60
# 14996  5024328              -2      C           60
# 14997  5024328              -3      C           60
# 14998  5024328              -4      0           60
# 14999  5024328              -5      0           60
#
# [15000 rows x 4 columns]

# %%
#Verify the data type for the new Credit Score value, then change to an integer
credit['CREDIT_SCORE'].dtype
# Out:
# dtype('O')

# %%
credit['CREDIT_SCORE']=credit['CREDIT_SCORE'].astype(int)
credit['CREDIT_SCORE'].dtype
# Out:
# dtype('int32')

# %%
credit['ID']=credit['ID'].astype(int)
credit['ID'].dtype
# Out:
# dtype('int32')

# %%
credit2=credit[['ID', 'CREDIT_SCORE']].copy()
credit2
# Out:
#             ID  CREDIT_SCORE
# 0      5008804            60
# 1      5008804            60
# 2      5008804            60
# 3      5008804            60
# 4      5008804            60
# ...        ...           ...
# 14995  5024328            60
# 14996  5024328            60
# 14997  5024328            60
# 14998  5024328            60
# 14999  5024328            60
#
# [15000 rows x 2 columns]

# %%
credit2['ID']=credit2['ID'].astype(int)
credit2['CREDIT_SCORE']=credit2['CREDIT_SCORE'].astype(int)

# %%
#Calculate the average credit score based on the points assigned to each of the 6 months
credit3=credit2.groupby('ID')['CREDIT_SCORE'].mean().round(2)
credit3
# Out:
# ID
# 5008804    60.00
# 5008805    60.00
# 5008806    60.00
# 5008810    60.00
# 5008811    60.00
#            ...
# 5024320    60.00
# 5024321    60.00
# 5024324    58.33
# 5024326    60.00
# 5024328    60.00
# Name: CREDIT_SCORE, Length: 2500, dtype: float64

# %%
credit4=credit3.to_frame()
credit4
# Out:
#          CREDIT_SCORE
# ID
# 5008804         60.00
# 5008805         60.00
# 5008806         60.00
# 5008810         60.00
# 5008811         60.00
# ...               ...
# 5024320         60.00
# 5024321         60.00
# 5024324         58.33
# 5024326         60.00
# 5024328         60.00
#
# [2500 rows x 1 columns]

# %%
#make sure we converted the series to the dataframe
credit4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 5008804 to 5024328
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CREDIT_SCORE  2500 non-null   float64
# dtypes: float64(1)
# memory usage: 39.1 KB

# %%
#exported score before and after calculated mean to verify data integrity
credit4.to_csv('./data/credit4.csv')
credit2.to_csv('./data/credit2.csv')

# %%
#Begin to calculate the application record score based on the biographic data. 
#First assign a the partial points towards the car ownership.

# %%
conditions2=[
    (application['FLAG_OWN_CAR']=='Y'),
    (application['FLAG_OWN_CAR']=='N')
    
]

# %%
values2=['6','0']

# %%
application['CAR_SCORE']=np.select(conditions2,values2)

# %%
application[['ID','FLAG_OWN_CAR','CAR_SCORE',]]
# Out:
#            ID FLAG_OWN_CAR CAR_SCORE
# 0     5008804            Y         6
# 1     5008805            Y         6
# 2     5008806            Y         6
# 3     5008810            N         0
# 4     5008811            N         0
# ...       ...          ...       ...
# 2495  5024320            N         0
# 2496  5024321            N         0
# 2497  5024324            N         0
# 2498  5024326            N         0
# 2499  5024328            N         0
#
# [2500 rows x 3 columns]

# %%
#Assign the partial points towards the realty ownership.

# %%
conditions3=[
    (application['FLAG_OWN_REALTY']=='Y'),
    (application['FLAG_OWN_REALTY']=='N')
    
]

# %%
values3=['6','0']

# %%
application['REALTY_SCORE']=np.select(conditions3,values3)

# %%
application[['ID','FLAG_OWN_REALTY','REALTY_SCORE',]]
# Out:
#            ID FLAG_OWN_REALTY REALTY_SCORE
# 0     5008804               Y            6
# 1     5008805               Y            6
# 2     5008806               Y            6
# 3     5008810               Y            6
# 4     5008811               Y            6
# ...       ...             ...          ...
# 2495  5024320               Y            6
# 2496  5024321               Y            6
# 2497  5024324               Y            6
# 2498  5024326               Y            6
# 2499  5024328               Y            6
#
# [2500 rows x 3 columns]

# %%
#Assign the partial points based on the Income Type

# %%
conditions4=[
    (application['NAME_INCOME_TYPE']=='Pensioner'),
    (application['NAME_INCOME_TYPE']=='Commercial associate'),
    (application['NAME_INCOME_TYPE']=='Working'),
    (application['NAME_INCOME_TYPE']=='State servant'),
    (application['NAME_INCOME_TYPE']=='Student'),
    
]

# %%
values4=['8','6','5','7','3']

# %%
application['INCOME_TYPE_SCORE']=np.select(conditions4,values4)

# %%
application[['ID','NAME_INCOME_TYPE','INCOME_TYPE_SCORE',]]
# Out:
#            ID      NAME_INCOME_TYPE INCOME_TYPE_SCORE
# 0     5008804               Working                 5
# 1     5008805               Working                 5
# 2     5008806               Working                 5
# 3     5008810  Commercial associate                 6
# 4     5008811  Commercial associate                 6
# ...       ...                   ...               ...
# 2495  5024320             Pensioner                 8
# 2496  5024321             Pensioner                 8
# 2497  5024324             Pensioner                 8
# 2498  5024326             Pensioner                 8
# 2499  5024328  Commercial associate                 6
#
# [2500 rows x 3 columns]

# %%
#Assign the partial points based on the Family Status

# %%
conditions5=[
    (application['NAME_FAMILY_STATUS']=='Married'),
    (application['NAME_FAMILY_STATUS']=='Single / not married'),
    (application['NAME_FAMILY_STATUS']=='Civil marriage'),
    (application['NAME_FAMILY_STATUS']=='Separated'),
    (application['NAME_FAMILY_STATUS']=='Widow'),
    
]

# %%
values5=['6','2','4','3','4']

# %%
application['FAMILY_STATUS_SCORE']=np.select(conditions5,values5)

# %%
application[['ID','NAME_FAMILY_STATUS','FAMILY_STATUS_SCORE',]]
# Out:
#            ID    NAME_FAMILY_STATUS FAMILY_STATUS_SCORE
# 0     5008804        Civil marriage                   4
# 1     5008805        Civil marriage                   4
# 2     5008806               Married                   6
# 3     5008810  Single / not married                   2
# 4     5008811  Single / not married                   2
# ...       ...                   ...                 ...
# 2495  5024320               Married                   6
# 2496  5024321               Married                   6
# 2497  5024324               Married                   6
# 2498  5024326               Married                   6
# 2499  5024328               Married                   6
#
# [2500 rows x 3 columns]

# %%
#Assign the partial points based on the Housing Type

# %%
conditions6=[
    (application['NAME_HOUSING_TYPE']=='House / apartment'),
    (application['NAME_HOUSING_TYPE']=='With parents'),
    (application['NAME_HOUSING_TYPE']=='Municipal apartment'),
    (application['NAME_HOUSING_TYPE']=='Rented apartment'),
    (application['NAME_HOUSING_TYPE']=='Co-op apartment'),
    (application['NAME_HOUSING_TYPE']=='Office apartment')
]

# %%
values6=['4','3','1','2','3','2']

# %%
application['HOUSING_SCORE']=np.select(conditions6,values6)

# %%
application[['ID','NAME_HOUSING_TYPE','HOUSING_SCORE',]]
# Out:
#            ID  NAME_HOUSING_TYPE HOUSING_SCORE
# 0     5008804   Rented apartment             2
# 1     5008805   Rented apartment             2
# 2     5008806  House / apartment             4
# 3     5008810  House / apartment             4
# 4     5008811  House / apartment             4
# ...       ...                ...           ...
# 2495  5024320  House / apartment             4
# 2496  5024321  House / apartment             4
# 2497  5024324  House / apartment             4
# 2498  5024326  House / apartment             4
# 2499  5024328  House / apartment             4
#
# [2500 rows x 3 columns]

# %%
#Implementing the partial credit scoring based on the income bracket customers fall under.

# %%
conditions7=[
    (application['AMT_INCOME_TOTAL']<126000),
    (application['AMT_INCOME_TOTAL']>=126000) & (application['AMT_INCOME_TOTAL']<180000),
    (application['AMT_INCOME_TOTAL']>=180000) & (application['AMT_INCOME_TOTAL']<225000),
    (application['AMT_INCOME_TOTAL']>=225000)
]

# %%
values7=['4','6','8','10']

# %%
application['INCOME_SCORE']=np.select(conditions7,values7)

# %%
application[['ID','AMT_INCOME_TOTAL','INCOME_SCORE',]]
# Out:
#            ID  AMT_INCOME_TOTAL INCOME_SCORE
# 0     5008804            427500           10
# 1     5008805            427500           10
# 2     5008806            112500            4
# 3     5008810            270000           10
# 4     5008811            270000           10
# ...       ...               ...          ...
# 2495  5024320            121500            4
# 2496  5024321            121500            4
# 2497  5024324            121500            4
# 2498  5024326            121500            4
# 2499  5024328            225000           10
#
# [2500 rows x 3 columns]

# %%
application['CAR_SCORE']=application['CAR_SCORE'].astype(int)
application['REALTY_SCORE']=application['REALTY_SCORE'].astype(int)
application['INCOME_TYPE_SCORE']=application['INCOME_TYPE_SCORE'].astype(int)
application['FAMILY_STATUS_SCORE']=application['FAMILY_STATUS_SCORE'].astype(int)
application['HOUSING_SCORE']=application['HOUSING_SCORE'].astype(int)
application['INCOME_SCORE']=application['INCOME_SCORE'].astype(int)

# %%
#Begin totaling up the partial scores

# %%
scores_list=['CAR_SCORE',
                   'REALTY_SCORE',
                   'INCOME_TYPE_SCORE',
                    'FAMILY_STATUS_SCORE',
                    'HOUSING_SCORE',
                    'INCOME_SCORE']

# %%
application['APPLICATION_SCORE']=application[scores_list].sum(axis=1)

# %%
application[['ID','CAR_SCORE',
                   'REALTY_SCORE',
                   'INCOME_TYPE_SCORE',
                    'FAMILY_STATUS_SCORE',
                    'HOUSING_SCORE',
                    'INCOME_SCORE', 'APPLICATION_SCORE']]
# Out:
#            ID  CAR_SCORE  REALTY_SCORE  INCOME_TYPE_SCORE  \
# 0     5008804          6             6                  5
# 1     5008805          6             6                  5
# 2     5008806          6             6                  5
# 3     5008810          0             6                  6
# 4     5008811          0             6                  6
# ...       ...        ...           ...                ...
# 2495  5024320          0             6                  8
# 2496  5024321          0             6                  8
# 2497  5024324          0             6                  8
# 2498  5024326          0             6                  8
# 2499  5024328          0             6                  6
#
#       FAMILY_STATUS_SCORE  HOUSING_SCORE  INCOME_SCORE  APPLICATION_SCORE
# 0                       4              2            10                 33
# 1                       4              2            10                 33
# ...

# %%
#Now that we have calculated the credit points based on the 6 months credit payment history
#AND the credit points for the biographic data, we can merge the 2 dataframes together and calculate the overall score.

# %%
credit_score_final=pd.merge(application,credit4,on='ID')
credit_score_final
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y             0
# 1     5008805           M            Y               Y             0
# 2     5008806           M            Y               Y             0
# 3     5008810           F            N               Y             0
# 4     5008811           F            N               Y             0
# ...       ...         ...          ...             ...           ...
# 2495  5024320           F            N               Y             0
# 2496  5024321           F            N               Y             0
# 2497  5024324           F            N               Y             0
# 2498  5024326           F            N               Y             0
# 2499  5024328           F            N               Y             0
#
#       AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
sum_column = credit_score_final["APPLICATION_SCORE"] + credit_score_final["CREDIT_SCORE"]
credit_score_final['FINAL_SCORE'] = sum_column
credit_score_final
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y             0
# 1     5008805           M            Y               Y             0
# 2     5008806           M            Y               Y             0
# 3     5008810           F            N               Y             0
# 4     5008811           F            N               Y             0
# ...       ...         ...          ...             ...           ...
# 2495  5024320           F            N               Y             0
# 2496  5024321           F            N               Y             0
# 2497  5024324           F            N               Y             0
# 2498  5024326           F            N               Y             0
# 2499  5024328           F            N               Y             0
#
#       AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
credit_score_final.to_csv('./data/credit_score_final.csv')

# %%
#Understanding our finals scores
credit_score_final['FINAL_SCORE'].describe()
# Out:
# count    2500.000000
# mean       86.881756
# std         6.773853
# min        27.000000
# 25%        83.000000
# 50%        87.000000
# 75%        91.000000
# max       100.000000
# Name: FINAL_SCORE, dtype: float64

# %%
evaluation_criteria_dictionary
# Out:
#             Column Title           Points
# 0                      -                -
# 1       NAME_INCOME_TYPE  Points Assigned
# 2              Pensioner                8
# 3   Commercial associate                6
# 4                Working                5
# 5          State servant                7
# 6                Student                3
# 7                      -                -
# 8     NAME_FAMILY_STATUS  Points Assigned
# 9                Married                6
# 10  Single / not married                2
# 11        Civil marriage                4
# 12             Separated                3
# 13                 Widow                4
# 14                     -                -
# 15     NAME_HOUSING_TYPE  Points Assigned
# 16     House / apartment                4
# 17          With parents                3
# 18   Municipal apartment                1
# 19      Rented apartment                2
# 20       Co-op apartment                3
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_INCOME_TYPE', y='INCOME_TYPE_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_FAMILY_STATUS', y='FAMILY_STATUS_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_FAMILY_STATUS', y='APPLICATION_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_FAMILY_STATUS', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_FAMILY_STATUS', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_HOUSING_TYPE', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='FLAG_OWN_CAR', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='FLAG_OWN_REALTY', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_HOUSING_TYPE', y='HOUSING_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(30,20))
sns.set(font_scale=1)
sns.jointplot(x='AMT_INCOME_TOTAL', y='INCOME_SCORE', hue="NAME_INCOME_TYPE", data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(30,20))
sns.set(font_scale=1)
sns.jointplot(x='AMT_INCOME_TOTAL', y='INCOME_SCORE', data=credit_score_final, kind='reg')
plt.grid()

# %%
plt.figure(figsize=(30,20))
sns.set(font_scale=.7)
sns.jointplot(x='NAME_INCOME_TYPE', y='AMT_INCOME_TOTAL', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.lineplot(x='AMT_INCOME_TOTAL', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(20,14))
sns.set(font_scale=2)
sns.lineplot(x='AMT_INCOME_TOTAL', y='FINAL_SCORE', hue="NAME_INCOME_TYPE", data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(20,14))
sns.set(font_scale=2)
sns.lineplot(x='AMT_INCOME_TOTAL', y='FINAL_SCORE', hue="FLAG_OWN_CAR", data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(20,14))
sns.set(font_scale=2)
sns.lineplot(x='AMT_INCOME_TOTAL', y='FINAL_SCORE', hue="FLAG_OWN_REALTY", data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_INCOME_TYPE', y='AMT_INCOME_TOTAL', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_INCOME_TYPE', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='AMT_INCOME_TOTAL', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='NAME_INCOME_TYPE', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=[9,7])
sns.set(font_scale=1)
credit_score_final['NAME_INCOME_TYPE'].value_counts().plot.pie()
plt.show()

# %%
credit_score_final['NAME_INCOME_TYPE'].value_counts()
# Out:
# Working                 1267
# Commercial associate     621
# Pensioner                423
# State servant            183
# Student                    6
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
by_income=credit_score_final.groupby('NAME_INCOME_TYPE')['FINAL_SCORE'].mean().round(2)
by_income
# Out:
# NAME_INCOME_TYPE
# Commercial associate    88.12
# Pensioner               87.32
# State servant           88.73
# Student                 85.00
# Working                 85.87
# Name: FINAL_SCORE, dtype: float64

# %%
#The student category is not representative because our sample size for students is too small.
by_income2=credit_score_final.groupby('NAME_INCOME_TYPE')['CREDIT_SCORE'].mean().round(2)
by_income2
# Out:
# NAME_INCOME_TYPE
# Commercial associate    57.98
# Pensioner               58.14
# State servant           58.31
# Student                 60.00
# Working                 58.22
# Name: CREDIT_SCORE, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='CODE_GENDER', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
credit_score_final['CODE_GENDER'].value_counts()
# Out:
# F    1666
# M     834
# Name: CODE_GENDER, dtype: int64

# %%
by_gender=credit_score_final.groupby('CODE_GENDER')['FINAL_SCORE'].mean().round(2)
by_gender
# Out:
# CODE_GENDER
# F    85.88
# M    88.88
# Name: FINAL_SCORE, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='CODE_GENDER', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
by_gender=credit_score_final.groupby('CODE_GENDER')['CREDIT_SCORE'].mean().round(2)
by_gender
# Out:
# CODE_GENDER
# F    58.26
# M    57.96
# Name: CREDIT_SCORE, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='CNT_CHILDREN', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1)
sns.barplot(x='CNT_FAM_MEMBERS', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(30,23))
sns.set(font_scale=1)
sns.barplot(x='OCCUPATION_TYPE', y='FINAL_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=(30,23))
sns.set(font_scale=1)
sns.barplot(x='OCCUPATION_TYPE', y='CREDIT_SCORE', data=credit_score_final)
plt.grid()

# %%
plt.figure(figsize=[9,7])
sns.set(font_scale=1)
credit_score_final['OCCUPATION_TYPE'].value_counts().plot.pie()
plt.show()

# %%
new=credit_score_final[['ID','NAME_INCOME_TYPE','DAYS_BIRTH', 'DAYS_EMPLOYED','CREDIT_SCORE','FINAL_SCORE']]

# %%
analysis=new.replace(to_replace =365243,
                 value =0)

# %%
analysis
# Out:
#            ID      NAME_INCOME_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  CREDIT_SCORE  \
# 0     5008804               Working      -12005          -4542         60.00
# 1     5008805               Working      -12005          -4542         60.00
# 2     5008806               Working      -21474          -1134         60.00
# 3     5008810  Commercial associate      -19110          -3051         60.00
# 4     5008811  Commercial associate      -19110          -3051         60.00
# ...       ...                   ...         ...            ...           ...
# 2495  5024320             Pensioner      -23407              0         60.00
# 2496  5024321             Pensioner      -23407              0         60.00
# 2497  5024324             Pensioner      -23407              0         58.33
# 2498  5024326             Pensioner      -23407              0         60.00
# 2499  5024328  Commercial associate      -17401          -9559         60.00
#
#       FINAL_SCORE
# 0           93.00
# ...

# %%
analysis['DAYS_BIRTH']=analysis['DAYS_BIRTH'].apply(abs)

# %%
analysis['DAYS_EMPLOYED']=analysis['DAYS_EMPLOYED'].apply(abs)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='DAYS_EMPLOYED', y='FINAL_SCORE', hue='NAME_INCOME_TYPE', data=analysis)
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED', ylabel='FINAL_SCORE'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='DAYS_EMPLOYED', y='CREDIT_SCORE', hue='NAME_INCOME_TYPE', data=analysis)
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED', ylabel='CREDIT_SCORE'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='DAYS_BIRTH', y='FINAL_SCORE', data=analysis)
# Out:
# <AxesSubplot:xlabel='DAYS_BIRTH', ylabel='FINAL_SCORE'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='DAYS_BIRTH', y='CREDIT_SCORE', data=analysis)
# Out:
# <AxesSubplot:xlabel='DAYS_BIRTH', ylabel='CREDIT_SCORE'>

# %%
plt.figure(figsize=(20,14))
sns.set(font_scale=2)
sns.scatterplot(x='AMT_INCOME_TOTAL', y='FINAL_SCORE', hue="NAME_INCOME_TYPE", data=credit_score_final)
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='FINAL_SCORE'>

# %%
plt.figure(figsize=(30,20))
sns.set(font_scale=2)
sns.scatterplot(x='AMT_INCOME_TOTAL', y='CREDIT_SCORE', hue="NAME_INCOME_TYPE", data=credit_score_final)
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='CREDIT_SCORE'>

# %%
application_raw = pd.read_csv('./data/application-record-raw.csv')

# %%
credit_raw = pd.read_csv('./data/credit-record-raw.csv')

# %%
application_raw.shape
# Out:
# (438557, 18)

# %%
credit_raw.shape
# Out:
# (1048575, 3)

# %%
application.shape
# Out:
# (2500, 25)

# %%
credit.shape
# Out:
# (15000, 4)

# %%
evaluation_criteria_dictionary
# Out:
#             Column Title           Points
# 0                      -                -
# 1       NAME_INCOME_TYPE  Points Assigned
# 2              Pensioner                8
# 3   Commercial associate                6
# 4                Working                5
# 5          State servant                7
# 6                Student                3
# 7                      -                -
# 8     NAME_FAMILY_STATUS  Points Assigned
# 9                Married                6
# 10  Single / not married                2
# 11        Civil marriage                4
# 12             Separated                3
# 13                 Widow                4
# 14                     -                -
# 15     NAME_HOUSING_TYPE  Points Assigned
# 16     House / apartment                4
# 17          With parents                3
# 18   Municipal apartment                1
# 19      Rented apartment                2
# 20       Co-op apartment                3
# ...

# %%
application_record_dictionary
# Out:
#            Feature name               Explanation  \
# 0                    ID             Client number
# 1           CODE_GENDER                    Gender
# 2          FLAG_OWN_CAR            Is there a car
# 3       FLAG_OWN_REALTY       Is there a property
# 4          CNT_CHILDREN        Number of children
# 5      AMT_INCOME_TOTAL             Annual income
# 6      NAME_INCOME_TYPE           Income category
# 7   NAME_EDUCATION_TYPE           Education level
# 8    NAME_FAMILY_STATUS            Marital status
# 9     NAME_HOUSING_TYPE             Way of living
# 10           DAYS_BIRTH                  Birthday
# 11        DAYS_EMPLOYED  Start date of employment
# 12           FLAG_MOBIL   Is there a mobile phone
# 13      FLAG_WORK_PHONE     Is there a work phone
# 14           FLAG_PHONE          Is there a phone
# 15           FLAG_EMAIL         Is there an email
# 16      OCCUPATION_TYPE                Occupation
# 17      CNT_FAM_MEMBERS               Family size
#
# ...

# %%
credit_record_dictionary
# Out:
#      Feature name    Explanation  \
# 0              ID  Client number
# 1  MONTHS_BALANCE   Record month
# 2          STATUS         Status
#
#                                                                                                                                                                                                                         Remarks
# 0                                                                                                                                                                                                                             -
# 1                                                                                                 The month of the extracted data is the starting point, backwards, 0 is the current month, -1 is the previous month, and so on
# ...
